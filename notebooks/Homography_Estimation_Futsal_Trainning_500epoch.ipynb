# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ikVjDqzcmFtjn9uSWQmL")
project = rf.workspace("salmans-workspace-fqyrz").project("futsal-jwihs")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 86.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 137.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Futsal-3 in yolov8:: 100%|██████████| 330/330 [00:00<00:00, 9221.14it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.8 MB/s eta 0:00:00
# ...

# %%
# !yolo mode=train task=pose model=yolov8l-pose.pt data= /content/Futsal-3/data.yaml  epochs=500 imgsz=640 mosaic=0.0
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import shutil
import os

output_directory = '/content/runs/pose/train'
output_filename = 'Homography Estimation Fustal 500 epoch'

if os.path.exists(output_directory):
  shutil.make_archive(output_filename, 'zip', output_directory)
  print(f"Successfully zipped '{output_directory}' to '{output_filename}.zip'")
else:
  print(f"Error: Directory '{output_directory}' not found.")
# Out:
# Successfully zipped '/content/runs/pose/train' to 'Homography Estimation Fustal 500 epoch.zip'
