# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ikVjDqzcmFtjn9uSWQmL")
project = rf.workspace("personal-zhpji").project("futsal-detection-y4jjv")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 62.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 95.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Futsal-Detection-1 in yolo26:: 100%|██████████| 1424/1424 [00:00<00:00, 2435.11it/s]

# %%
# !pip install ultralytics

# %%
# !yolo mode=train task=detect model=yolo26l.pt data= /content/Futsal-Detection-1/data.yaml  epochs=250 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import shutil
import os

output_directory = '/content/runs/detect/train'
output_filename = 'detection Fustal 250 epoch'

if os.path.exists(output_directory):
  shutil.make_archive(output_filename, 'zip', output_directory)
  print(f"Successfully zipped '{output_directory}' to '{output_filename}.zip'")
else:
  print(f"Error: Directory '{output_directory}' not found.")
# Out:
# Successfully zipped '/content/runs/detect/train' to 'detection Fustal 250 epoch.zip'
